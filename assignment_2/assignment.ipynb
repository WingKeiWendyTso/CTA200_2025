# %%
#part1
def f(x):
    """This funciton is a mathematical function that takes the input x and 
    return x^3-x^2-1"""
    return x**3-x**2-1

def df(x):
    """This function is a mathematical function that takes the input x and 
    return the derivative of function f(x), which is 3x^2-2x"""
    return 3*x**2-2*x

print(f(3))
print(df(3))
# Out:
# 17
# 21

# %%
#part2
def newton(f, df, x0, epsilon=1e-6, max iter=30):
    """This function is to use newton iteration to find the roots of f
    with its derivative df"""
